# %%
import requests
url = 'http://www.boxofficemojo.com/movies/?id=transformers4.htm'

# %%
url[url.find("//")+2:]
# Out:
# 'www.boxofficemojo.com/movies/?id=transformers4.htm'

# %%
import urlpa

# %%
response = requests.get(url)
response
# Out:
# <Response [200]>

# %%
response.status_code
# Out:
# 200

# %%
page = response.text

# %%
page
# Out:
# u'<!DOCTYPE html PUBLIC "-//W3C//DTD HTML 4.01 Transitional//EN" "http://www.w3.org/TR/html4/loose.dtd">\n<html lang="en">\n<head>\n<meta http-equiv="Content-type" content="text/html;charset=iso-8859-1">\n<title>Transformers: Age of Extinction (2014) - Box Office Mojo</title>\n\n<style type="text/css">\ntable.chart-wide { width: 100%; }\n</style>\n<META name="keywords" content="transformers: age of extinction, movie, film, box office, result, records, charts, revenue, opening weekend, gross, worldwide, overseas, foreign, news, reviews, articles, stories, story, analysis, revenue, release date, mpaa rating, genre, running time, length, budget, production budget, distributor, studio, paramount, theatrical summary, theatrical, daily box office results, weekend box office results, weekly box office, weekly box office, international box office summary, worldwide box office summary, similar movies, image gallery, images, pictures, photos, box office mojo">\n<META name="description" content
# ...

# %%
from bs4 import BeautifulSoup
soup = BeautifulSoup(page)

# %%
print soup.prettify()
# Out:
# <!DOCTYPE html PUBLIC "-//W3C//DTD HTML 4.01 Transitional//EN" "http://www.w3.org/TR/html4/loose.dtd">
# <html lang="en">
#  <head>
#   <meta content="text/html;charset=utf-8" http-equiv="Content-type"/>
#   <title>
#    Transformers: Age of Extinction (2014) - Box Office Mojo
#   </title>
#   <style type="text/css">
#    table.chart-wide { width: 100%; }
#   </style>
#   <meta content="transformers: age of extinction, movie, film, box office, result, records, charts, revenue, opening weekend, gross, worldwide, overseas, foreign, news, reviews, articles, stories, story, analysis, revenue, release date, mpaa rating, genre, running time, length, budget, production budget, distributor, studio, paramount, theatrical summary, theatrical, daily box office results, weekend box office results, weekly box office, weekly box office, international box office summary, worldwide box office summary, similar movies, image gallery, images, pictures, photos, box office mojo" name="keywords"/>
# ...

# %%
soup.title.text
# Out:
# u'Transformers: Age of Extinction (2014) - Box Office Mojo'

# %%
soup.find(text = 'The Players')
# Out:
# u'The Players'
